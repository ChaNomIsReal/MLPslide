# %%
import numpy as np

np.random.seed(3) # To make repeatable
LEARNING_RATE = 0.1
index_list = [0, 1, 2, 3] # Used to randomize order

# Define training examples.
x_train = [np.array([1.0, -1.0, -1.0]),
           np.array([1.0, -1.0, 1.0]),
           np.array([1.0, 1.0, -1.0]),
           np.array([1.0, 1.0, 1.0])]
y_train = [0.0, 1.0, 1.0, 0.0] # Output (ground truth)

# %%
print(type(x_train))
# Out:
# <class 'list'>

# %%
def neuron_w(input_count):
    weights = np.zeros( input_count+1)
    for i in range(0, (input_count)):
        weights[i] = np.random.uniform(-1.0, 1.0)
    return weights

# %% [markdown]
# n_w_o  weight of output layer 1x3  (bias, w1, w2)
# n_w_h1 weight of hidden layer (2, 3)

# %%
n_w_o = [neuron_w(2)]
n_w_h1 = [neuron_w(2), neuron_w(2)]
n_yo = [0]
n_yh1 = [0, 0]
n_grad_o = [0]
n_grad_hd1 =  [0, 0]

# %%
print(n_w_o)
print(type(n_w_o))
# Out:
# [array([0.10159581, 0.41629565, 0.        ])]
# <class 'list'>

# %%
print(n_w_h1)
# Out:
# [array([-0.41819052,  0.02165521,  0.        ]), array([0.78589391, 0.79258618, 0.        ])]

# %%
def show_learning():
    print('Current weights:')
    for i, w in enumerate(n_w_o):
        print('Output neuron ', i,  ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    for i, w in enumerate(n_w_h1):
        print('Hidden 1 neuron ', i,  ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    print('----------------')

# %%
def forward_pass(x):
    global n_yo, n_yh1
    n_yh1[0] = np.tanh(np.dot(n_w_h1[0], x)) # hidden 1
    n_yh1[1] = np.tanh(np.dot(n_w_h1[1], x)) # hidden 2
    n2_inputs = np.array([1.0, n_yh1[0], n_yh1[1]]) # 1.0 is bias
    zo = np.dot(n_w_o, n2_inputs)
    n_yo = 1.0 / (1.0 + np.exp(- zo))  #sigmoid

# %%
def backward_pass(y_truth):
    global n_grad_o, n_grad_hd1
    error = -(y_truth - n_yo) # Derivative of loss-func
    derivative_sigmoid  = n_yo * (1.0 - n_yo) # Logistic derivative
    n_grad_o = error * derivative_sigmoid
    derivative_tanh = 1.0 - n_yh1[0]**2 # tanh derivative
    n_grad_hd1[0] = n_w_o[0][1] * n_grad_o * derivative_tanh
    derivative_tanh = 1.0 - n_yh1[1]**2 # tanh derivative
    n_grad_hd1[1] = n_w_o[0][2] * n_grad_o * derivative_tanh
    print('n_grad_o:', n_grad_o)
    print('n_grad_hd1:', n_grad_hd1[0], '   ', n_grad_hd1[1])

# %%
def adjust_weights(x):
    global n_w_o ,  n_w_h1
    n2_inputs = np.array([1.0, n_yh1[0], n_yh1[1]]) # 1.0 is bias
    n_w_o -= (n2_inputs * LEARNING_RATE * n_grad_o)
    n_w_h1[0] -= (x * LEARNING_RATE * n_grad_hd1[0])
    n_w_h1[1] -= (x * LEARNING_RATE * n_grad_hd1[1])

# %%
# Network training loop.
all_correct = False
MAX_EPOCH = 50
for x in range(MAX_EPOCH):
    print('epoch: ', x)
    all_correct = True
    np.random.shuffle(index_list) # Randomize order
    for i in index_list: # Train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() # Show updated weights
    for i in range(len(x_train)): # Check if converged
        forward_pass(x_train[i])
        print('x1 =', '%4.1f' % x_train[i][1], ', x2 =', '%4.1f' % x_train[i][2],
              'y_train =', '%4.1f' % y_train[i], 'y =', '%.4f' % n_yo)
        if(((y_train[i] < 0.5) and (n_yo >= 0.5))
                or ((y_train[i] >= 0.5) and (n_yo < 0.5))):
            all_correct = False
# Out:
# epoch:  0
# n_grad_o: [-0.11788547]
# n_grad_hd1: [-0.03940293]     [-0.00265855]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [-0.12733799]
# n_grad_hd1: [-0.03458676]     [-0.01519306]
# Current weights:
# Output neuron  0 : w0 =  0.14 , w1 =  0.35 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [0.12417601]
# n_grad_hd1: [0.0377683]     [0.01501895]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [0.13089338]
# n_grad_hd1: [0.03957339]     [0.00197867]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4891
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4868
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5272
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5173
# epoch:  1
# n_grad_o: [0.12917478]
# n_grad_hd1: [0.03924301]     [0.00176301]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.10
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [-0.1292791]
# n_grad_hd1: [-0.03591955]     [-0.01276166]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.10
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [-0.11861799]
# n_grad_hd1: [-0.03938294]     [-0.00248527]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [0.12333673]
# n_grad_hd1: [0.03818034]     [0.01366444]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4889
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4868
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5276
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5177
# epoch:  2
# n_grad_o: [-0.11774054]
# n_grad_hd1: [-0.03939402]     [-0.00276665]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [0.13062713]
# n_grad_hd1: [0.03943063]     [0.00197091]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.14
# ----------------
# n_grad_o: [0.12220273]
# n_grad_hd1: [0.03841322]     [0.01352402]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [-0.12939821]
# n_grad_hd1: [-0.03576109]     [-0.01456699]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4886
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4867
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5279
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5179
# epoch:  3
# n_grad_o: [-0.11766059]
# n_grad_hd1: [-0.03937711]     [-0.00281977]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [0.12290714]
# n_grad_hd1: [0.03796604]
# <ipython-input-15-9a09156c877e>:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   'y_train =', '%4.1f' % y_train[i], 'y =', '%.4f' % n_yo)
#  [0.01528437]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [-0.12834263]
# n_grad_hd1: [-0.03507838]     [-0.01621156]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [0.13106998]
# n_grad_hd1: [0.03958252]     [0.00204192]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4882
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4865
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5281
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5181
# epoch:  4
# n_grad_o: [-0.12827267]
# n_grad_hd1: [-0.03516977]     [-0.01486619]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [-0.11655503]
# n_grad_hd1: [-0.03827142]     [-0.00290263]
# Current weights:
# Output neuron  0 : w0 =  0.13 , w1 =  0.35 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [0.13171758]
# n_grad_hd1: [0.03914125]     [0.00204693]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [0.12307382]
# n_grad_hd1: [0.03812071]     [0.01424638]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4878
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4863
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5282
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5182
# epoch:  5
# n_grad_o: [0.129378]
# n_grad_hd1: [0.03926157]     [0.00184561]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [0.12110726]
# n_grad_hd1: [0.03832139]     [0.01278019]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [-0.12024936]
# n_grad_hd1: [-0.04119747]     [-0.00274499]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# n_grad_o: [-0.12946214]
# n_grad_hd1: [-0.03567226]     [-0.01526898]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.15
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4877
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4864
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5288
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5187
# epoch:  6
# n_grad_o: [0.12184839]
# n_grad_hd1: [0.0378797]     [0.01457001]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.12885656]
# n_grad_hd1: [0.03969641]     [0.00188804]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.13025298]
# n_grad_hd1: [-0.03631667]     [-0.01429034]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.11
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.11905614]
# n_grad_hd1: [-0.03999612]     [-0.00284438]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4875
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4865
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5294
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5192
# epoch:  7
# n_grad_o: [-0.12827787]
# n_grad_hd1: [-0.03504956]     [-0.0156277]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.12285835]
# n_grad_hd1: [0.03761179]     [0.01520259]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.11711961]
# n_grad_hd1: [-0.03889333]     [-0.00316517]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.13136518]
# n_grad_hd1: [0.03960008]     [0.0021346]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4871
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4864
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5296
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5194
# epoch:  8
# n_grad_o: [-0.11719443]
# n_grad_hd1: [-0.03929142]     [-0.00311547]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.12252372]
# n_grad_hd1: [0.03786666]     [0.01638405]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.13038917]
# n_grad_hd1: [0.0398952]     [0.00211377]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.12949807]
# n_grad_hd1: [-0.03557718]     [-0.01603357]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4868
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4863
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5299
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5197
# epoch:  9
# n_grad_o: [0.12972339]
# n_grad_hd1: [0.03927766]     [0.00194448]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.11892318]
# n_grad_hd1: [-0.04037563]     [-0.00292398]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.12168715]
# n_grad_hd1: [0.03827273]     [0.01508077]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.12948945]
# n_grad_hd1: [-0.03552694]     [-0.01631343]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4866
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4863
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5304
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5202
# epoch:  10
# n_grad_o: [0.12983184]
# n_grad_hd1: [0.03928922]     [0.00197134]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.12
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [-0.11878639]
# n_grad_hd1: [-0.04033863]     [-0.00299268]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.16
# ----------------
# n_grad_o: [0.12162367]
# n_grad_hd1: [0.03824669]     [0.01533808]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [-0.12948094]
# n_grad_hd1: [-0.03547714]     [-0.01659603]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4863
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4864
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5309
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5206
# epoch:  11
# n_grad_o: [0.12149455]
# n_grad_hd1: [0.03776519]     [0.01578712]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [-0.12920473]
# n_grad_hd1: [-0.03545755]     [-0.01705759]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [0.13037634]
# n_grad_hd1: [0.03946042]     [0.00205418]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.13
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [-0.11849008]
# n_grad_hd1: [-0.0398683]     [-0.00318016]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4861
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4864
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5314
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5211
# epoch:  12
# n_grad_o: [-0.12830152]
# n_grad_hd1: [-0.03485935]     [-0.0169564]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.05 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [0.12248169]
# n_grad_hd1: [0.03749598]     [0.01645044]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [-0.11653275]
# n_grad_hd1: [-0.03875541]     [-0.00350903]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [0.1317843]
# n_grad_hd1: [0.03963132]     [0.00225433]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4856
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4863
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5316
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5213
# epoch:  13
# n_grad_o: [-0.12833618]
# n_grad_hd1: [-0.03484448]     [-0.01720907]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [-0.11555537]
# n_grad_hd1: [-0.03804457]     [-0.00348794]
# Current weights:
# Output neuron  0 : w0 =  0.13 , w1 =  0.35 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [0.13241351]
# n_grad_hd1: [0.03918722]     [0.00225953]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.17
# ----------------
# n_grad_o: [0.12239475]
# n_grad_hd1: [0.03792902]     [0.01641892]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4852
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4861
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5318
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5214
# epoch:  14
# n_grad_o: [0.1211845]
# n_grad_hd1: [0.03770457]     [0.01647233]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.11746811]
# n_grad_hd1: [-0.03989268]     [-0.00361058]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.12845429]
# n_grad_hd1: [-0.03471357]     [-0.01903197]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [0.13188715]
# n_grad_hd1: [0.03965009]     [0.0022939]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4848
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5322
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5217
# epoch:  15
# n_grad_o: [-0.11647879]
# n_grad_hd1: [-0.03916923]     [-0.00359144]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.12756456]
# n_grad_hd1: [-0.03414144]     [-0.01887783]
# Current weights:
# Output neuron  0 : w0 =  0.13 , w1 =  0.35 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [0.12294362]
# n_grad_hd1: [0.03745334]     [0.0184814]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [0.13193043]
# n_grad_hd1: [0.03966089]     [0.00231354]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4843
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4858
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5324
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5219
# epoch:  16
# n_grad_o: [0.1209581]
# n_grad_hd1: [0.03767103]     [0.01694352]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.07
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.11729411]
# n_grad_hd1: [-0.0398965]     [-0.00375964]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [0.13097653]
# n_grad_hd1: [0.03996987]     [0.00229237]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.12961593]
# n_grad_hd1: [-0.03532481]     [-0.01818769]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4840
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5329
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5224
# epoch:  17
# n_grad_o: [-0.1162813]
# n_grad_hd1: [-0.03915336]     [-0.00374168]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [0.13164944]
# n_grad_hd1: [0.039531]     [0.00230112]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.18
# ----------------
# n_grad_o: [-0.12873877]
# n_grad_hd1: [-0.03476171]     [-0.01805473]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [0.12198033]
# n_grad_hd1: [0.037857]     [0.01740617]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4836
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4858
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5332
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5227
# epoch:  18
# n_grad_o: [-0.12845202]
# n_grad_hd1: [-0.03472059]     [-0.01855326]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [0.13144405]
# n_grad_hd1: [0.03908095]     [0.00219801]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [-0.1169782]
# n_grad_hd1: [-0.03913181]     [-0.00359978]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [0.12186812]
# n_grad_hd1: [0.03783262]     [0.01766845]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4831
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4857
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5336
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5230
# epoch:  19
# n_grad_o: [0.13047679]
# n_grad_hd1: [0.03938192]     [0.00217792]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [0.11987507]
# n_grad_hd1: [0.03802724]     [0.0161795]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.14
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [-0.11878973]
# n_grad_hd1: [-0.04096227]     [-0.00373704]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [-0.12962445]
# n_grad_hd1: [-0.03520981]     [-0.01908505]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4829
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5342
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5236
# epoch:  20
# n_grad_o: [-0.12843071]
# n_grad_hd1: [-0.0346281]     [-0.01916842]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [0.13166373]
# n_grad_hd1: [0.03911301]     [0.00225247]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.11669038]
# n_grad_hd1: [-0.03907014]     [-0.00376677]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.19
# ----------------
# n_grad_o: [0.12168659]
# n_grad_hd1: [0.03778081]     [0.01824229]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4824
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4858
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5346
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5240
# epoch:  21
# n_grad_o: [0.12045547]
# n_grad_hd1: [0.03754624]     [0.01828436]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [0.13010267]
# n_grad_hd1: [0.03985399]     [0.00224615]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.13042694]
# n_grad_hd1: [-0.03580665]     [-0.0185331]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.11741736]
# n_grad_hd1: [-0.03972023]     [-0.00395612]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4821
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5352
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5246
# epoch:  22
# n_grad_o: [-0.12840928]
# n_grad_hd1: [-0.03454761]     [-0.01979683]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [0.13187811]
# n_grad_hd1: [0.03913692]     [0.00230595]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.11641393]
# n_grad_hd1: [-0.03900545]     [-0.0039408]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [0.12148687]
# n_grad_hd1: [0.03772932]     [0.01881775]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4816
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5356
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5250
# epoch:  23
# n_grad_o: [0.13091424]
# n_grad_hd1: [0.0394461]     [0.00228409]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.11737748]
# n_grad_hd1: [-0.04014238]     [-0.00398573]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.37 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [-0.1287218]
# n_grad_hd1: [-0.03453047]     [-0.01990264]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.20
# ----------------
# n_grad_o: [0.12137774]
# n_grad_hd1: [0.03770423]     [0.01911713]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4812
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5361
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5255
# epoch:  24
# n_grad_o: [0.13102615]
# n_grad_hd1: [0.03946616]     [0.00231126]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.15
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [-0.1295484]
# n_grad_hd1: [-0.03515759]     [-0.01907906]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.05 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [0.12046489]
# n_grad_hd1: [0.03765085]     [0.01809593]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [-0.11700048]
# n_grad_hd1: [-0.03964297]     [-0.00423226]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4808
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5367
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5260
# epoch:  25
# n_grad_o: [-0.1152091]
# n_grad_hd1: [-0.03894179]     [-0.00442736]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [-0.12755621]
# n_grad_hd1: [-0.03378045]     [-0.02186974]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.35 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [0.13343404]
# n_grad_hd1: [0.03934034]     [0.00254725]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [0.12112738]
# n_grad_hd1: [0.03765638]     [0.0196725]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4803
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5369
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5263
# epoch:  26
# n_grad_o: [-0.11513075]
# n_grad_hd1: [-0.03895723]     [-0.0045167]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [-0.12758651]
# n_grad_hd1: [-0.03376396]     [-0.02215391]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.35 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [0.13348834]
# n_grad_hd1: [0.0393614]     [0.00256627]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.21
# ----------------
# n_grad_o: [0.12097284]
# n_grad_hd1: [0.03763499]     [0.01992747]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4797
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4858
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5372
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5265
# epoch:  27
# n_grad_o: [-0.11504884]
# n_grad_hd1: [-0.03897145]     [-0.00460828]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [-0.12761431]
# n_grad_hd1: [-0.03374641]     [-0.0224422]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.35 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [0.12157586]
# n_grad_hd1: [0.03716425]     [0.02178235]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [0.13299731]
# n_grad_hd1: [0.03984266]     [0.00259871]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4791
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4857
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5375
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5268
# epoch:  28
# n_grad_o: [0.13132178]
# n_grad_hd1: [0.03954237]     [0.00239915]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.16
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [-0.11683757]
# n_grad_hd1: [-0.04013171]     [-0.00444808]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [-0.12879641]
# n_grad_hd1: [-0.03439554]     [-0.02144783]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [0.12069045]
# n_grad_hd1: [0.03759067]     [0.02050307]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4786
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4857
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5381
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5274
# epoch:  29
# n_grad_o: [-0.11479946]
# n_grad_hd1: [-0.0389549]     [-0.00480875]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.22
# ----------------
# n_grad_o: [-0.12762446]
# n_grad_hd1: [-0.03368258]     [-0.0230864]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.36 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [0.12128584]
# n_grad_hd1: [0.03711751]     [0.02236241]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [0.13317962]
# n_grad_hd1: [0.03988052]     [0.0026443]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4780
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4856
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5384
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5276
# epoch:  30
# n_grad_o: [0.11925902]
# n_grad_hd1: [0.03732046]     [0.02078864]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [-0.11556529]
# n_grad_hd1: [-0.03966457]     [-0.00503608]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [0.13224114]
# n_grad_hd1: [0.04021447]     [0.00261821]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [-0.12969384]
# n_grad_hd1: [-0.03485234]     [-0.02258277]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4775
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4857
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5390
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5282
# epoch:  31
# n_grad_o: [0.13162387]
# n_grad_hd1: [0.03959274]     [0.002471]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.17
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [-0.1164406]
# n_grad_hd1: [-0.04008898]     [-0.00475697]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [0.11918603]
# n_grad_hd1: [0.03778166]     [0.02084452]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# n_grad_o: [-0.1296585]
# n_grad_hd1: [-0.03479596]     [-0.02293692]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.23
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4771
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4859
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5396
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5288
# epoch:  32
# n_grad_o: [0.11901837]
# n_grad_hd1: [0.03726014]     [0.02141154]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [0.13121146]
# n_grad_hd1: [0.04005866]     [0.00251259]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.38 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [-0.13044002]
# n_grad_hd1: [-0.03540108]     [-0.02218809]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.18
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [-0.11597144]
# n_grad_hd1: [-0.03952782]     [-0.00505113]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.19
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.24
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4767
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4861
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5403
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5295
# epoch:  33
# n_grad_o: [-0.11418535]
# n_grad_hd1: [-0.03883001]     [-0.00523478]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [0.119687]
# n_grad_hd1: [0.03727431]     [0.02301891]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [-0.12842656]
# n_grad_hd1: [-0.03402706]     [-0.02494862]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [0.13365131]
# n_grad_hd1: [0.03993292]     [0.00273992]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.24
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4760
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4861
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5407
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5299
# epoch:  34
# n_grad_o: [-0.11407625]
# n_grad_hd1: [-0.03882795]     [-0.00534477]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [-0.12753151]
# n_grad_hd1: [-0.03348094]     [-0.02473013]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.24
# ----------------
# n_grad_o: [0.12059067]
# n_grad_hd1: [0.036981]     [0.02387829]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [0.13372107]
# n_grad_hd1: [0.03995289]     [0.0027582]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4753
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5410
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5302
# epoch:  35
# n_grad_o: [-0.12839486]
# n_grad_hd1: [-0.03409894]     [-0.02401384]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [0.1196378]
# n_grad_hd1: [0.03692552]     [0.02287474]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.08
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [-0.11369149]
# n_grad_hd1: [-0.03836159]     [-0.00565353]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [0.13380096]
# n_grad_hd1: [0.03996872]     [0.00277748]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4747
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5414
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5306
# epoch:  36
# n_grad_o: [-0.1138699]
# n_grad_hd1: [-0.03883915]     [-0.0055707]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [0.11914592]
# n_grad_hd1: [0.03720154]     [0.02383306]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [-0.12844132]
# n_grad_hd1: [-0.03395388]     [-0.02592688]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# n_grad_o: [0.13388906]
# n_grad_hd1: [0.0399865]     [0.0027959]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.25
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4740
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4860
# ...
# ----------------
# n_grad_o: [0.13398617]
# n_grad_hd1: [0.03999992]     [0.00281519]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4734
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4861
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5422
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5314
# epoch:  38
# n_grad_o: [-0.12837265]
# n_grad_hd1: [-0.03401546]     [-0.02500128]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [0.11911993]
# n_grad_hd1: [0.0368415]     [0.02375161]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.36 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [0.13287049]
# n_grad_hd1: [0.03986246]     [0.00268885]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [-0.11524193]
# n_grad_hd1: [-0.0394882]     [-0.00575812]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4728
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4862
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5428
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5320
# epoch:  39
# n_grad_o: [0.13245928]
# n_grad_hd1: [0.0397374]     [0.00264869]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [0.11710635]
# n_grad_hd1: [0.03750774]     [0.02192539]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.38 , w2 =  0.20
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [-0.11619467]
# n_grad_hd1: [-0.04064792]     [-0.00582224]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.26
# ----------------
# n_grad_o: [-0.12954504]
# n_grad_hd1: [-0.03450265]     [-0.02569423]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4724
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4865
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5436
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5328
# epoch:  40
# n_grad_o: [-0.12827563]
# n_grad_hd1: [-0.03390109]     [-0.02574023]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [0.11882516]
# n_grad_hd1: [0.036777]     [0.02444206]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.36 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [0.13316684]
# n_grad_hd1: [0.03990956]     [0.00273996]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [-0.11485588]
# n_grad_hd1: [-0.03940894]     [-0.00602205]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4717
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4867
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5441
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5334
# epoch:  41
# n_grad_o: [0.11754939]
# n_grad_hd1: [0.0369998]     [0.02412678]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [-0.12910883]
# n_grad_hd1: [-0.03436268]     [-0.02667982]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.36 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [0.13330796]
# n_grad_hd1: [0.03993011]     [0.00276335]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [-0.1146751]
# n_grad_hd1: [-0.03937138]     [-0.00615715]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4711
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4869
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5448
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5340
# epoch:  42
# n_grad_o: [0.13288679]
# n_grad_hd1: [0.03980925]     [0.00272182]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.27
# ----------------
# n_grad_o: [0.11663866]
# n_grad_hd1: [0.03741211]     [0.02292293]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.38 , w2 =  0.21
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [-0.13024745]
# n_grad_hd1: [-0.03499954]     [-0.02577013]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [-0.11447099]
# n_grad_hd1: [-0.03931235]     [-0.00629253]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4706
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4872
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5455
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5348
# epoch:  43
# n_grad_o: [-0.11269347]
# n_grad_hd1: [-0.03861946]     [-0.00645573]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [-0.12726526]
# n_grad_hd1: [-0.03312065]     [-0.02781281]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.36 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [0.11909071]
# n_grad_hd1: [0.03671417]     [0.02670805]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.09
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [0.1347566]
# n_grad_hd1: [0.04012979]     [0.00294851]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4698
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4872
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5459
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5352
# epoch:  44
# n_grad_o: [0.13312881]
# n_grad_hd1: [0.03985574]     [0.00276383]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.22
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [-0.11451654]
# n_grad_hd1: [-0.03982712]     [-0.00634023]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [-0.1285018]
# n_grad_hd1: [-0.0337879]     [-0.02694659]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.28
# ----------------
# n_grad_o: [0.11815395]
# n_grad_hd1: [0.03714577]     [0.02545916]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4691
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4874
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5465
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5358
# epoch:  45
# n_grad_o: [0.11681824]
# n_grad_hd1: [0.03685747]     [0.02540618]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [-0.11321816]
# n_grad_hd1: [-0.0392758]     [-0.00690755]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.25
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [-0.12808557]
# n_grad_hd1: [-0.03353308]     [-0.02914011]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.25
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [0.13500304]
# n_grad_hd1: [0.04017969]     [0.00298753]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4683
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4875
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5470
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5364
# epoch:  46
# n_grad_o: [-0.1280411]
# n_grad_hd1: [-0.03362888]     [-0.02790659]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [0.13442914]
# n_grad_hd1: [0.03958799]     [0.00285626]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [-0.11302445]
# n_grad_hd1: [-0.03859999]     [-0.00669588]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.06 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.29
# ----------------
# n_grad_o: [0.1177452]
# n_grad_hd1: [0.03708043]     [0.0260808]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4676
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4877
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5475
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5369
# epoch:  47
# n_grad_o: [0.13350048]
# n_grad_hd1: [0.03994166]     [0.00282441]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.37 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.06 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [0.11565716]
# n_grad_hd1: [0.03723593]     [0.02449176]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.38 , w2 =  0.23
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [-0.1148432]
# n_grad_hd1: [-0.04044708]     [-0.00694372]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.37 , w2 =  0.24
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [-0.12923781]
# n_grad_hd1: [-0.03413236]     [-0.02863737]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.25
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4670
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4880
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5483
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5378
# epoch:  48
# n_grad_o: [-0.11186498]
# n_grad_hd1: [-0.03852542]     [-0.00717096]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.37 , w2 =  0.26
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [0.11699022]
# n_grad_hd1: [0.03680674]     [0.0275894]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.26
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.08 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [-0.12793533]
# n_grad_hd1: [-0.03339015]     [-0.03020951]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.26
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.31
# ----------------
# n_grad_o: [0.13538141]
# n_grad_hd1: [0.04025931]     [0.00304243]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.25
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.31
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4661
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4881
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5488
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5382
# epoch:  49
# n_grad_o: [-0.11173271]
# n_grad_hd1: [-0.03852414]     [-0.00732176]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.37 , w2 =  0.26
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.11
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.30
# ----------------
# n_grad_o: [0.11675462]
# n_grad_hd1: [0.03677129]     [0.02787157]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.26
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.08 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.80 , w2 =  0.31
# ----------------
# n_grad_o: [-0.12790191]
# n_grad_hd1: [-0.03335518]     [-0.03054741]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.36 , w2 =  0.27
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.31
# ----------------
# n_grad_o: [0.13548269]
# n_grad_hd1: [0.04028284]     [0.00305606]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.37 , w2 =  0.25
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.07 , w2 = -0.10
# Hidden 1 neuron  1 : w0 =  0.80 , w1 =  0.79 , w2 =  0.31
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.4653
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.4883
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5492
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5387

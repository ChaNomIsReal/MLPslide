# %%
import numpy as np

np.random.seed(3) # To make repeatable
LEARNING_RATE = 0.1
index_list = [0, 1, 2, 3] # Used to randomize order

# Define training examples.
x_train = [np.array([1.0, -1.0, -1.0]),
           np.array([1.0, -1.0, 1.0]),
           np.array([1.0, 1.0, -1.0]),
           np.array([1.0, 1.0, 1.0])]
y_train = [0.0, 1.0, 1.0, 0.0] # Output (ground truth)

# %%
print(type(x_train))
# Out:
# <class 'list'>

# %%
def neuron_w(input_count):
    weights = np.zeros( input_count+1)
    for i in range(0, (input_count)):
        weights[i] = np.random.uniform(-1.0, 1.0)
    return weights

# %% [markdown]
# n_w_o  weight of output layer 1x3  (bias, w1, w2)
# n_w_h1 weight of hidden layer (2, 3)

# %%
n_w_o = [neuron_w(2)]
n_w_h1 = [neuron_w(2), neuron_w(2)]
n_w_h2 = [neuron_w(1), neuron_w(1)]
n_yo = [0]
n_yh1 = [0,0,0,0]
n_yh2 = [0,0]
n_grad_o = [0]
n_grad_hd1 =  [0, 0]

# %%
print(n_w_o)
print(type(n_w_o))
# Out:
# [array([0.10159581, 0.41629565, 0.        ])]
# <class 'list'>

# %%
print(n_w_h1)
print(n_w_h2)
# Out:
# [array([-0.41819052,  0.02165521,  0.        ]), array([0.78589391, 0.79258618, 0.        ])]
# [array([-0.74882938,  0.        ]), array([-0.58551424,  0.        ])]

# %%
def show_learning():
    print('Current weights:')
    for i, w in enumerate(n_w_o):
        print('Output neuron ', i,  ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    for i, w in enumerate(n_w_h1):
        print('Hidden 1 neuron ', i,  ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1], ', w2 =',
              '%5.2f' % w[2])
    for i, w in enumerate(n_w_h2):
        print('Hidden 2 neuron ', i,  ': w0 =', '%5.2f' % w[0],
              ', w1 =', '%5.2f' % w[1])
    print('----------------')

# %%
def forward_pass(x):
    global n_yo, n_yh1,n_yh2
    n_yh1[0] = np.tanh(np.dot(n_w_h1[0], n_w_h1[0])) # hidden w11
    n_yh1[1] = np.tanh(np.dot(n_w_h1[0], n_w_h1[1])) # hidden w12
    n_yh1[2] = np.tanh(np.dot(n_w_h1[1] ,n_w_h1[0])) # hidden w21
    n_yh1[3] = np.tanh(np.dot(n_w_h1[1] ,n_w_h1[1] )) # hidden w22
    n_yh2[0] = np.tanh(np.dot(n_yh1[0],n_yh1[1] )) # hidden w11
    n_yh2[1] = np.tanh(np.dot(n_yh1[2], n_yh1[3])) # hidden w21
    n2_inputs = np.array([1.0, n_yh2[0], n_yh2[1]])
    zo = np.dot(n_w_o, n2_inputs)
    n_yo = 1.0 / (1.0 + np.exp(- zo))  #sigmoid

# %%
def backward_pass(y_truth):
    global n_grad_o, n_grad_hd1
    error = -(y_truth - n_yo) # Derivative of loss-func
    derivative_sigmoid  = n_yo * (1.0 - n_yo) # Logistic derivative
    n_grad_o = error * derivative_sigmoid
    derivative_tanh = 1.0 - n_yh2[0]**2 # tanh derivative
    n_grad_hd1[0] = n_w_o[0][1] * n_grad_o * derivative_tanh
    derivative_tanh = 1.0 - n_yh2[1]**2 # tanh derivative
    n_grad_hd1[1] = n_w_o[0][2] * n_grad_o * derivative_tanh
    print('n_grad_o:', n_grad_o)
    print('n_grad_hd1:', n_grad_hd1[0], '   ', n_grad_hd1[1])

# %%
def adjust_weights(x):
    global n_w_o ,  n_w_h1, n_w_h2
    n2_inputs = np.array([1.0, n_yh2[0], n_yh2[1]]) # 1.0 is bias
    n_w_o -= (n2_inputs * LEARNING_RATE * n_grad_o)
    n_w_h1[0] -= (x * LEARNING_RATE * n_grad_hd1[0])
    n_w_h1[1] -= (x * LEARNING_RATE * n_grad_hd1[1])

# %%
# Network training loop.
all_correct = False
MAX_EPOCH = 50
for x in range(MAX_EPOCH):
    print('epoch: ', x)
    all_correct = True
    np.random.shuffle(index_list) # Randomize order
    for i in index_list: # Train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() # Show updated weights
    for i in range(len(x_train)): # Check if converged
        forward_pass(x_train[i])
        print('x1 =', '%4.1f' % x_train[i][1], ', x2 =', '%4.1f' % x_train[i][2],
              'y_train =', '%4.1f' % y_train[i], 'y =', '%.4f' % n_yo)
        if(((y_train[i] < 0.5) and (n_yo >= 0.5))
                or ((y_train[i] >= 0.5) and (n_yo < 0.5))):
            all_correct = False
# Out:
# epoch:  0
# n_grad_o: [0.13055567]
# n_grad_hd1: [0.05413225]     [-0.00036803]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.11987166]
# n_grad_hd1: [-0.04977348]     [-2.18941882e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13051299]
# n_grad_hd1: [0.05412442]     [-0.00033683]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.11995268]
# n_grad_hd1: [-0.04980885]     [-4.28015802e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5228
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5228
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5228
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5228
# epoch:  1
# n_grad_o: [-0.11905852]
# n_grad_hd1: [-0.04937056]     [0.00028645]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.42 , w2 = -0.01
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.02 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13115749]
# n_grad_hd1: [0.05431602]     [-0.00067525]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.11914902]
# n_grad_hd1: [-0.04941275]     [0.00025344]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.42 , w2 = -0.01
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13110637]
# n_grad_hd1: [0.05430529]     [-0.00064059]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5221
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5221
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5221
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5221
# epoch:  2
# n_grad_o: [0.13027141]
# n_grad_hd1: [0.05402805]     [-0.00025029]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12020817]
# n_grad_hd1: [-0.04992656]     [-0.00013051]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13020846]
# n_grad_hd1:
# <ipython-input-20-9a09156c877e>:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   'y_train =', '%4.1f' % y_train[i], 'y =', '%.4f' % n_yo)
# [0.05400583]     [-0.0002199]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12031594]
# n_grad_hd1: [-0.0499687]     [-0.00015792]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5216
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5216
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5216
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5216
# epoch:  3
# n_grad_o: [0.1301456]
# n_grad_hd1: [0.05398122]     [-0.00019911]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12039087]
# n_grad_hd1: [-0.05000116]     [-0.00017753]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13005765]
# n_grad_hd1: [0.05393983]     [-0.00017813]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12046151]
# n_grad_hd1: [-0.05003429]     [-0.00020519]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5210
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5210
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5210
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5210
# epoch:  4
# n_grad_o: [0.13002313]
# n_grad_hd1: [0.05393554]     [-0.00014903]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1205343]
# n_grad_hd1: [-0.05006574]     [-0.00022413]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12993638]
# n_grad_hd1: [0.05389445]     [-0.000129]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12060289]
# n_grad_hd1: [-0.05009789]     [-0.00025113]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5205
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5205
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5205
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5205
# epoch:  5
# n_grad_o: [-0.11967657]
# n_grad_hd1: [-0.04964809]     [9.26377392e-05]
# Current weights:
# Output neuron  0 : w0 =  0.12 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.11875379]
# n_grad_hd1: [-0.04920362]     [0.00042291]
# Current weights:
# Output neuron  0 : w0 =  0.13 , w1 =  0.41 , w2 = -0.01
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13140246]
# n_grad_hd1: [0.05437428]     [-0.00082269]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1305976]
# n_grad_hd1: [0.05411635]     [-0.00042752]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5198
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5198
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5198
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5198
# epoch:  6
# n_grad_o: [0.1297536]
# n_grad_hd1: [0.05383616]     [-3.94038556e-05]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12084766]
# n_grad_hd1: [-0.05020804]     [-0.00032672]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12969493]
# n_grad_hd1: [0.05381235]     [-2.15566659e-05]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12087907]
# n_grad_hd1: [-0.05022881]     [-0.00034489]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5193
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5193
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5193
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5193
# epoch:  7
# n_grad_o: [0.12964045]
# n_grad_hd1: [0.05379339]     [5.09374744e-06]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1209783]
# n_grad_hd1: [-0.05026646]     [-0.00036868]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12958321]
# n_grad_hd1: [0.05377004]     [2.22097493e-05]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12100762]
# n_grad_hd1: [-0.05028629]     [-0.00038635]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5189
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5189
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5189
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5189
# epoch:  8
# n_grad_o: [-0.12011425]
# n_grad_hd1: [-0.04984418]     [-4.46362095e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.02 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13028862]
# n_grad_hd1: [0.05399163]     [-0.00031648]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12018965]
# n_grad_hd1: [-0.04987929]     [-7.32117413e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13025]
# n_grad_hd1: [0.0539855]     [-0.00028655]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5183
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5183
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5183
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5183
# epoch:  9
# n_grad_o: [-0.12026533]
# n_grad_hd1: [-0.04991231]     [-9.30416956e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13018606]
# n_grad_hd1: [0.05396031]     [-0.00026578]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12030686]
# n_grad_hd1: [-0.04993729]     [-0.00011289]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13012489]
# n_grad_hd1: [0.05393888]     [-0.00023621]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5177
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5177
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5177
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5177
# epoch:  10
# n_grad_o: [0.12927277]
# n_grad_hd1: [0.05365605]     [0.0001499]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12840426]
# n_grad_hd1: [0.0533679]     [0.00053551]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12233481]
# n_grad_hd1: [-0.0509244]     [-0.00088548]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12144274]
# n_grad_hd1: [-0.05047633]     [-0.00052414]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5174
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5174
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5174
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5174
# epoch:  11
# n_grad_o: [-0.12051583]
# n_grad_hd1: [-0.05002327]     [-0.00017101]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12997528]
# n_grad_hd1: [0.05387975]     [-0.00018312]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12058849]
# n_grad_hd1: [-0.05005445]     [-0.00018938]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12988979]
# n_grad_hd1: [0.05383929]     [-0.00016357]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5168
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5168
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5168
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5168
# epoch:  12
# n_grad_o: [0.12906133]
# n_grad_hd1: [0.05357536]     [0.0002309]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12818945]
# n_grad_hd1: [0.05328612]     [0.00061556]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12257045]
# n_grad_hd1: [-0.05103023]     [-0.00096502]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12167885]
# n_grad_hd1: [-0.05058134]     [-0.00060073]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5165
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5165
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5165
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5165
# epoch:  13
# n_grad_o: [-0.12075185]
# n_grad_hd1: [-0.05012737]     [-0.0002449]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.11985732]
# n_grad_hd1: [-0.04968535]     [9.69940182e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1305276]
# n_grad_hd1: [0.05403977]     [-0.0004747]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12970914]
# n_grad_hd1: [0.05377805]     [-8.17151489e-05]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5159
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5159
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5159
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5159
# epoch:  14
# n_grad_o: [0.12885006]
# n_grad_hd1: [0.05349303]     [0.00030282]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12800826]
# n_grad_hd1: [0.0532242]     [0.00068907]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12280277]
# n_grad_hd1: [-0.05113116]     [-0.00102765]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12187808]
# n_grad_hd1: [-0.05067411]     [-0.0006625]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5156
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5156
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5156
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5156
# epoch:  15
# n_grad_o: [-0.12098589]
# n_grad_hd1: [-0.05022896]     [-0.00031031]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1200916]
# n_grad_hd1: [-0.04978613]     [3.42733006e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.41 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13033295]
# n_grad_hd1: [0.05396248]     [-0.0004072]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12948237]
# n_grad_hd1: [0.05368093]     [-1.47053355e-05]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5151
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5151
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5151
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5151
# epoch:  16
# n_grad_o: [-0.12112501]
# n_grad_hd1: [-0.05029178]     [-0.0003564]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12942974]
# n_grad_hd1: [0.05366235]     [1.08603227e-05]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12118599]
# n_grad_hd1: [-0.05032]     [-0.00038037]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12940385]
# n_grad_hd1: [0.05366089]     [3.61780222e-05]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5146
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5146
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5146
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5146
# epoch:  17
# n_grad_o: [-0.12124707]
# n_grad_hd1: [-0.05034606]     [-0.00039558]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12035307]
# n_grad_hd1: [-0.04990229]     [-4.78014992e-05]
# Current weights:
# Output neuron  0 : w0 =  0.11 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13011411]
# n_grad_hd1: [0.05387948]     [-0.00031941]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12925978]
# n_grad_hd1: [0.05359672]     [7.21726125e-05]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5141
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5141
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5141
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5141
# epoch:  18
# n_grad_o: [-0.12137868]
# n_grad_hd1: [-0.05040528]     [-0.0004392]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12048483]
# n_grad_hd1: [-0.04996102]     [-8.9783511e-05]
# Current weights:
# Output neuron  0 : w0 =  0.10 , w1 =  0.42 , w2 = -0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.13000317]
# n_grad_hd1: [0.05383757]     [-0.00027477]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12914694]
# n_grad_hd1: [0.0535542]     [0.00011636]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5136
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5136
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5136
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5136
# epoch:  19
# n_grad_o: [0.12830817]
# n_grad_hd1: [0.05328747]     [0.00050852]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12247729]
# n_grad_hd1: [-0.05093692]     [-0.00085518]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12826818]
# n_grad_hd1: [0.05326968]     [0.00051719]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12248274]
# n_grad_hd1: [-0.05094599]     [-0.00086674]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5133
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5133
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5133
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5133
# epoch:  20
# n_grad_o: [0.12823174]
# n_grad_hd1: [0.05325646]     [0.0005347]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12252347]
# n_grad_hd1: [-0.05096454]     [-0.0008838]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12822405]
# n_grad_hd1: [0.05326146]     [0.00055382]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1225657]
# n_grad_hd1: [-0.05098128]     [-0.00089208]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5130
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5130
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5130
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5130
# epoch:  21
# n_grad_o: [-0.12167479]
# n_grad_hd1: [-0.05053377]     [-0.00053135]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12897842]
# n_grad_hd1: [0.05349423]     [0.00019101]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12173045]
# n_grad_hd1: [-0.05055679]     [-0.00054419]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12890301]
# n_grad_hd1: [0.05345632]     [0.00020302]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5126
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5126
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5126
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5126
# epoch:  22
# n_grad_o: [-0.12178106]
# n_grad_hd1: [-0.05058042]     [-0.00056524]
# Current weights:
# Output neuron  0 : w0 =  0.09 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12888519]
# n_grad_hd1: [0.05345791]     [0.00022557]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12801204]
# n_grad_hd1: [0.05316818]     [0.00060683]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12276219]
# n_grad_hd1: [-0.05106756]     [-0.0009562]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5122
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5122
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5122
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5122
# epoch:  23
# n_grad_o: [0.12797893]
# n_grad_hd1: [0.05315602]     [0.00062273]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1271261]
# n_grad_hd1: [0.05288424]     [0.00100606]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12374747]
# n_grad_hd1: [-0.05155247]     [-0.00134949]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12282371]
# n_grad_hd1: [-0.05109213]     [-0.00097338]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5120
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5120
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5120
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5120
# epoch:  24
# n_grad_o: [-0.12193337]
# n_grad_hd1: [-0.05064378]     [-0.0006095]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.42 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12875101]
# n_grad_hd1: [0.05340188]     [0.00027031]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12194836]
# n_grad_hd1: [-0.05065688]     [-0.00062289]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12870762]
# n_grad_hd1: [0.05338613]     [0.00029072]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5116
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5116
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5116
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5116
# epoch:  25
# n_grad_o: [0.12783267]
# n_grad_hd1: [0.05309608]     [0.00067099]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12299533]
# n_grad_hd1: [-0.05115922]     [-0.00101733]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12776859]
# n_grad_hd1: [0.05306068]     [0.0006744]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12302885]
# n_grad_hd1: [-0.05117427]     [-0.00103196]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5113
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5113
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5113
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5113
# epoch:  26
# n_grad_o: [0.12776915]
# n_grad_hd1: [0.05306922]     [0.0006914]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12302569]
# n_grad_hd1: [-0.05117932]     [-0.00104107]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12210279]
# n_grad_hd1: [-0.05072315]     [-0.00067674]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1285705]
# n_grad_hd1: [0.05333096]     [0.00034512]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5110
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5110
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5110
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5110
# epoch:  27
# n_grad_o: [-0.12218505]
# n_grad_hd1: [-0.0507522]     [-0.00069347]
# Current weights:
# Output neuron  0 : w0 =  0.08 , w1 =  0.42 , w2 =  0.00
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12852791]
# n_grad_hd1: [0.05331267]     [0.00035525]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1276834]
# n_grad_hd1: [0.05304308]     [0.00073752]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12315238]
# n_grad_hd1: [-0.05123243]     [-0.00107633]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5107
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5107
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5107
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5107
# epoch:  28
# n_grad_o: [0.12762214]
# n_grad_hd1: [0.05300907]     [0.00073946]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12318362]
# n_grad_hd1: [-0.05124628]     [-0.00108984]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12759256]
# n_grad_hd1: [0.05299743]     [0.0007529]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12325273]
# n_grad_hd1: [-0.05126802]     [-0.00109986]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# ...
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12856263]
# n_grad_hd1: [0.05323342]     [0.00022033]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12771695]
# n_grad_hd1: [0.05296458]     [0.00060762]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5074
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5074
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5074
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5074
# epoch:  41
# n_grad_o: [0.12682768]
# n_grad_hd1: [0.05267023]     [0.00098363]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1240234]
# n_grad_hd1: [-0.05158896]     [-0.00134184]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.04 , w2 = -0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.123102]
# n_grad_hd1: [-0.0511298]     [-0.00096622]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12766694]
# n_grad_hd1: [0.05294388]     [0.00062979]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5072
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5072
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5072
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5072
# epoch:  42
# n_grad_o: [-0.12317103]
# n_grad_hd1: [-0.0511518]     [-0.00097692]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12760579]
# n_grad_hd1: [0.05290978]     [0.00063221]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1232405]
# n_grad_hd1: [-0.05117347]     [-0.00098743]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.127576]
# n_grad_hd1: [0.05289558]     [0.00063677]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5070
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5070
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5070
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5070
# epoch:  43
# n_grad_o: [-0.12323393]
# n_grad_hd1: [-0.05117717]     [-0.00099542]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12754783]
# n_grad_hd1: [0.05288474]     [0.00065007]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12330257]
# n_grad_hd1: [-0.05119839]     [-0.00100553]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12751883]
# n_grad_hd1: [0.0528708]     [0.00065428]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5067
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5067
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5067
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5067
# epoch:  44
# n_grad_o: [0.12665966]
# n_grad_hd1: [0.05259891]     [0.00104087]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12423733]
# n_grad_hd1: [-0.05166847]     [-0.00139722]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12331345]
# n_grad_hd1: [-0.05120613]     [-0.00101217]
# Current weights:
# Output neuron  0 : w0 =  0.07 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1274752]
# n_grad_hd1: [0.05285022]     [0.00066568]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5065
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5065
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5065
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5065
# epoch:  45
# n_grad_o: [0.12661554]
# n_grad_hd1: [0.05257822]     [0.0010521]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12574713]
# n_grad_hd1: [0.0523026]     [0.00143046]
# Current weights:
# Output neuron  0 : w0 =  0.03 , w1 =  0.42 , w2 =  0.02
# Hidden 1 neuron  0 : w0 = -0.45 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12516804]
# n_grad_hd1: [-0.05213908]     [-0.00179906]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12428478]
# n_grad_hd1: [-0.0516823]     [-0.00140251]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5065
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5065
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5065
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5065
# epoch:  46
# n_grad_o: [0.12659781]
# n_grad_hd1: [0.05256404]     [0.0010437]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.1242622]
# n_grad_hd1: [-0.05167833]     [-0.00140554]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 =  0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 =  0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.1265819]
# n_grad_hd1: [0.05255671]     [0.0010508]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12431694]
# n_grad_hd1: [-0.05169223]     [-0.00140853]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5064
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5064
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5064
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5064
# epoch:  47
# n_grad_o: [-0.12339249]
# n_grad_hd1: [-0.05122965]     [-0.00102266]
# Current weights:
# Output neuron  0 : w0 =  0.06 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.43 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12740121]
# n_grad_hd1: [0.05280956]     [0.00067492]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12650398]
# n_grad_hd1: [0.05251374]     [0.00105725]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 =  0.00
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12436165]
# n_grad_hd1: [-0.05171043]     [-0.00142803]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5062
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5062
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5062
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5062
# epoch:  48
# n_grad_o: [0.12652458]
# n_grad_hd1: [0.05252948]     [0.00106766]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12561672]
# n_grad_hd1: [0.05222919]     [0.0014406]
# Current weights:
# Output neuron  0 : w0 =  0.03 , w1 =  0.42 , w2 =  0.02
# Hidden 1 neuron  0 : w0 = -0.45 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12526165]
# n_grad_hd1: [-0.05216964]     [-0.00182538]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12434144]
# n_grad_hd1: [-0.05170509]     [-0.00143185]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5061
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5061
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5061
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5061
# epoch:  49
# n_grad_o: [0.12650711]
# n_grad_hd1: [0.05251922]     [0.00107534]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.02 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12439519]
# n_grad_hd1: [-0.05171837]     [-0.0014343]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.02
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [0.12649179]
# n_grad_hd1: [0.0525094]     [0.00107305]
# Current weights:
# Output neuron  0 : w0 =  0.04 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# n_grad_o: [-0.12437087]
# n_grad_hd1: [-0.05171365]     [-0.00143677]
# Current weights:
# Output neuron  0 : w0 =  0.05 , w1 =  0.42 , w2 =  0.01
# Hidden 1 neuron  0 : w0 = -0.44 , w1 =  0.03 , w2 = -0.01
# Hidden 1 neuron  1 : w0 =  0.79 , w1 =  0.79 , w2 = -0.00
# Hidden 2 neuron  0 : w0 = -0.75 , w1 =  0.00
# Hidden 2 neuron  1 : w0 = -0.59 , w1 =  0.00
# ----------------
# x1 = -1.0 , x2 = -1.0 y_train =  0.0 y = 0.5060
# x1 = -1.0 , x2 =  1.0 y_train =  1.0 y = 0.5060
# x1 =  1.0 , x2 = -1.0 y_train =  1.0 y = 0.5060
# x1 =  1.0 , x2 =  1.0 y_train =  0.0 y = 0.5060
